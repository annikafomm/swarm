# %% [markdown]
# source: https://scanpy.readthedocs.io/en/stable/tutorials/basics/clustering.html

# %%
import scanpy as sc
import matplotlib.pyplot as plt

sc.settings.set_figure_params(show=False, dpi=100)  # Disable auto show
sc.pl.highly_variable_genes(adata, save="_manual.png")

# Optional: show the figure manually
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 import scanpy as sc
#       2 import matplotlib.pyplot as plt
# ----> 4 sc.settings.set_figure_params(show=False, dpi=100)  # Disable auto show
#       5 sc.pl.highly_variable_genes(adata, save="_manual.png")
#       7 # Optional: show the figure manually
#
# File c:\Users\rebec\miniforge3\lib\site-packages\legacy_api_wrap\__init__.py:82, in legacy_api.<locals>.wrapper.<locals>.fn_compatible(*args_all, **kw)
#      79 @wraps(fn)
#      80 def fn_compatible(*args_all: P.args, **kw: P.kwargs) -> R:
#      81     if len(args_all) <= n_positional:
# ---> 82         return fn(*args_all, **kw)
#      84     args_pos: P.args
#      85     args_pos, args_rest = args_all[:n_positional], args_all[n_positional:]
#
# TypeError: ScanpyConfig.set_figure_params() got an unexpected keyword argument 'show'

# %%
# Core scverse libraries
import scanpy as sc
import anndata as ad

import os

sc.settings.set_figure_params(dpi=50, facecolor="white")

# %%
adata = sc.read_h5ad(os.path.join("..", "datasets", "GSM6592055_M8.h5ad"))
print(adata.obs["Sample_ID"].value_counts())
adata

# %% [markdown]
# # Quality Control

# %%
# mitochondrial genes, "MT-" for human, "Mt-" for mouse
adata.var["mt"] = adata.var_names.str.upper().str.startswith("MT-")
# ribosomal genes
adata.var["ribo"] = adata.var_names.str.upper().str.startswith(("RPS", "RPL"))
# hemoglobin genes
adata.var["hb"] = adata.var_names.str.upper().str.contains("^HB[^(P)]")

# %%
print(f"Mitochondrial genes: {round(adata.var['mt'].sum()/adata.n_vars *100, 1)}%")
print(f"Ribosomal genes: {round(adata.var['ribo'].sum()/adata.n_vars *100, 1)}%")
print(f"Hemoglobin genes: {round(adata.var['hb'].sum()/adata.n_vars *100, 1)}%")

# %%
sc.pp.calculate_qc_metrics(
    adata, qc_vars=["mt", "ribo", "hb"], inplace=True, log1p=True
)

# %%
sc.pl.violin(
    adata,
    ["n_genes_by_counts", "total_counts", "pct_counts_mt"],
    jitter=0.4,
    multi_panel=True,
)

# %%
sc.pl.scatter(adata, "total_counts", "n_genes_by_counts", color="pct_counts_mt")

# %%
sc.pp.filter_cells(adata, min_genes=100)
sc.pp.filter_genes(adata, min_cells=3)

# %% [markdown]
# # Doublet Detection

# %%
sc.pp.scrublet(adata)

# %%
print(adata.obs["predicted_doublet"].sum())

# %% [markdown]
# # Normalization

# %%
# Saving count data
adata.layers["counts"] = adata.X.copy()

# Normalizing to 1e4 total counts
sc.pp.normalize_total(adata, target_sum=1e4)
# Logarithmize the data
sc.pp.log1p(adata)

# %% [markdown]
# # Feature selection

# %%
adata.n_vars

# %%
sc.pp.highly_variable_genes(adata)
sc.pl.highly_variable_genes(adata)

# %% [markdown]
# # Dimensionality Reduction

# %%
sc.tl.pca(adata)
sc.pl.pca_variance_ratio(adata, n_pcs=50, log=True)

# %%
sc.pl.pca(
    adata,
    color=["cell_type", "cell_type", "pct_counts_mt", "pct_counts_mt"],
    dimensions=[(0, 1), (2, 3), (0, 1), (2, 3)],
    ncols=2,
    size=4,
)

# %% [markdown]
# # Nearest neighbor graph construction and visualization

# %%
sc.pp.neighbors(adata)

# %%
sc.tl.umap(adata)

sc.pl.umap(
    adata,
    color="cell_type",
    # Setting a smaller point size to get prevent overlap
    size=4,
)

# %% [markdown]
# # Clustering

# %%
import numpy as np
np.random.seed(1)

# Using the igraph implementation and a fixed number of iterations can be significantly faster, especially for larger datasets
sc.tl.leiden(adata, flavor="igraph", n_iterations=2)
sc.pl.umap(adata, color=["leiden"])

# %%
sc.pl.umap(
    adata,
    color=["leiden", "predicted_doublet", "doublet_score"],
    # increase horizontal space between panels
    wspace=0.5,
    size=3,
)

# %%
sc.pl.umap(
    adata,
    color=["leiden", "log1p_total_counts", "pct_counts_mt", "log1p_n_genes_by_counts"],
    wspace=0.5,
    ncols=2,
)
