# %%
import scanpy as sc
import pandas as pd
import anndata as ad
import os

path = "datasets"
dir = "output-XETG00125__0042682__3802__20240426__200549"

adata = sc.read_h5ad(os.path.join(path, f"{dir.split('_')[0]}_compact.h5ad"))
adata.var.head()
# Out:
#                gene_ids    feature_types   genome
# ABCC11  ENSG00000121270  Gene Expression  Unknown
# ACTA2   ENSG00000107796  Gene Expression  Unknown
# ACTG2   ENSG00000163017  Gene Expression  Unknown
# ADAM9   ENSG00000168615  Gene Expression  Unknown
# ADGRE5  ENSG00000123146  Gene Expression  Unknown
